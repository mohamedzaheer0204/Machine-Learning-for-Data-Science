# %% [markdown]
# www.linkedin.com/in/mohamed-zaheerudeen-m-s-790b95226
#
# # Roll number : 235229116
# ## Name : Mohamed Zaheerudeen
# ### LAB-2

# %% [markdown]
# ## Pizza Liking Prediction using KNN

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
pizza = pd.read_csv("pizza.csv")
pizza.head()
# Out:
#    age  weight  likePizza
# 0   50      65          0
# 1   20      55          1
# 2   15      40          1
# 3   70      65          0
# 4   30      70          1

# %%
pizza.shape
# Out:
# (6, 3)

# %%
pizza.columns
# Out:
# Index(['age', 'weight', 'likePizza'], dtype='object')

# %%
pizza.info
# Out:
# <bound method DataFrame.info of    age  weight  likePizza
# 0   50      65          0
# 1   20      55          1
# 2   15      40          1
# 3   70      65          0
# 4   30      70          1
# 5   75      60          0>

# %%
sns.relplot(x='age',y='weight',data=pizza,hue='likePizza')

# %%
sns.scatterplot(x=pizza['age'], y=pizza['weight'], hue=pizza['likePizza'])
# Out:
# <Axes: xlabel='age', ylabel='weight'>

# %%
sns.relplot(x='age',y='weight',data=pizza,kind='scatter');

# %%
Fix = ["age","weight"]
x = pizza[Fix]

# %%
x
# Out:
#    age  weight
# 0   50      65
# 1   20      55
# 2   15      40
# 3   70      65
# 4   30      70
# 5   75      60

# %%
y = pizza.likePizza

# %%
y
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# 5    0
# Name: likePizza, dtype: int64

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.dtypes
# Out:
# age       int64
# weight    int64
# dtype: object

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y.dtypes
# Out:
# dtype('int64')

# %%
piz_eat = KNeighborsClassifier(n_neighbors=2)

# %%
piz_eat.fit(x,y)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
piz_eat.predict(x)
# Out:
# array([0, 1, 1, 0, 1, 0], dtype=int64)

# %%
pre = [[25,50]]
print(piz_eat.predict(pre))
# Out:
# [1]
# C:\Users\moham\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
pre =[[60,60]]
print(piz_eat.predict(pre))
# Out:
# [0]
# C:\Users\moham\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
piz_eat1 = KNeighborsClassifier(n_neighbors=3)
piz_eat1.fit(x,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
pre = [[25,50]]
print(piz_eat1.predict(pre))
# Out:
# [1]
# C:\Users\moham\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
pre = [[60,60]]
print(piz_eat1.predict(pre))
# Out:
# [0]
# C:\Users\moham\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
y_pred = piz_eat.predict
y_pred
# Out:
# <bound method KNeighborsClassifier.predict of KNeighborsClassifier(n_neighbors=2)>

# %%
def accuracy(actual, pred):
    return sum(actual == pred) / float(actual.shape[0])

# %%
accuracy(y,y_pred)
# Out:
# 0.0

# %%
pizza1 = pd.read_csv("pizza_test.csv")

# %%
pizza1.head()
# Out:
#    age  weight  likePizza
# 0   48      68          1
# 1   35      45          1
# 2   15      40          0
# 3   55      65          0

# %%
pizza1.shape
# Out:
# (4, 3)

# %%
pizza1.columns
# Out:
# Index(['age', 'weight', 'likePizza'], dtype='object')

# %%
pizza1.info
# Out:
# <bound method DataFrame.info of    age  weight  likePizza
# 0   48      68          1
# 1   35      45          1
# 2   15      40          0
# 3   55      65          0>

# %%
Fix = ["age","weight"]
x = pizza1[Fix]

# %%
x
# Out:
#    age  weight
# 0   48      68
# 1   35      45
# 2   15      40
# 3   55      65

# %%
y = pizza1.likePizza

# %%
y
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# Name: likePizza, dtype: int64

# %%
pizza_eat = KNeighborsClassifier(n_neighbors=2)

# %%
pizza_eat.fit(x,y)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
pizza_eat.predict(x)
# Out:
# array([0, 0, 0, 0], dtype=int64)

# %%
def accuracy(actual, pred):
    return sum(actual == pred) / (float(actual.shape[0]))

# %%
y_pred = pizza_eat.predict(x)

# %%
accuracy(y,y_pred)
# Out:
# 0.5

# %%
scores = []

for k in range(1,4):
    best = KNeighborsClassifier(n_neighbors=k)
    best.fit(x,y)
    y_pred = best.predict(x)
    acc = accuracy(y,y_pred)
    scores.append((k, acc))

# %%
scores
# Out:
# [(1, 1.0), (2, 0.5), (3, 0.5)]

# %%
from sklearn import *

# %%
accuracy(y,y_pred)
# Out:
# 0.5
