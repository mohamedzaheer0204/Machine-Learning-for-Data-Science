# %% [markdown]
# www.linkedin.com/in/mohamed-zaheerudeen-m-s-790b95226
#
# # Roll number : 235229116
# ## Name : Mohamed Zaheerudeen
#
# ## Lab1:Warm up-Familiarity with data types and visualization

# %% [markdown]
# ### Roll no:235229108

# %%
import pandas as pd

# %% [markdown]
# ### 1. Read and display the files of tabular data

# %%
df=pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
df.size
# Out:
# 900

# %%
df.shape
# Out:
# (150, 6)

# %%
df.ndim
# Out:
# 2

# %%
print(df.head(5))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df.SepalLengthCm
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# ...

# %%
df.plot('Species','SepalLengthCm')

# %%
df.plot()

# %%
# importing pandas module
import pandas as pd
 
# reading csv file
data = pd.read_csv("iris.csv")
 
# dataframe.ndim
df_ndim = data.ndim
 
# series.ndim
series_ndim = data["SepalLengthCm"].ndim
 
# printing ndim
print("ndim of dataframe = {}\nndim of series ={}".
      format(df_ndim, series_ndim))
# Out:
# ndim of dataframe = 2
# ndim of series =1

# %%
import seaborn as a
g=a.pairplot(df,kind="reg")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df.plot(kind="bar")

# %%
df.plot(kind="hist")

# %%
df.plot.scatter(x="Id",y="SepalLengthCm")

# %%
from matplotlib import pyplot as plt
teams = ['Argentina', 'Canada', 'France', 'Morocco', ' Portugal']
won = [74, 43, 38, 51, 50]
fig = plt.figure(figsize =(8,8))
plt.pie(won,labels = teams)
# Out:
# ([<matplotlib.patches.Wedge at 0x1eeccb6d4a8>,
# ...
#  [Text(0.6767547496386895, 0.867181070389267, 'Argentina'),
#   Text(-0.7682138743498701, 0.7873039078122006, 'Canada'),
#   Text(-1.0788638084435536, -0.2145993542177412, 'France'),
#   Text(-0.306371658323559, -1.0564735713571223, 'Morocco'),
#   Text(0.8993432944667421, -0.6333890105596298, ' Portugal')])

# %% [markdown]
# ### "TSV" — tab-separated values (.tsv)

# %%
import pandas as pd 
df = pd.read_csv('FIFAtsv.txt',sep = '\t')
print(df)
# Out:
#     Id,SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCm,Species
# 0                        1,5.1,3.5,1.4,0.2,Iris-setosa
# 1                        2,4.9,3.0,1.4,0.2,Iris-setosa
# 2                        3,4.7,3.2,1.3,0.2,Iris-setosa
# 3                        4,4.6,3.1,1.5,0.2,Iris-setosa
# 4                        5,5.0,3.6,1.4,0.2,Iris-setosa
# 5                        6,5.4,3.9,1.7,0.4,Iris-setosa
# 6                        7,4.6,3.4,1.4,0.3,Iris-setosa
# 7                        8,5.0,3.4,1.5,0.2,Iris-setosa
# 8                        9,4.4,2.9,1.4,0.2,Iris-setosa
# 9                       10,4.9,3.1,1.5,0.1,Iris-setosa
# 10                      11,5.4,3.7,1.5,0.2,Iris-setosa
# 11                      12,4.8,3.4,1.6,0.2,Iris-setosa
# 12                      13,4.8,3.0,1.4,0.1,Iris-setosa
# 13                      14,4.3,3.0,1.1,0.1,Iris-setosa
# 14                      15,5.8,4.0,1.2,0.2,Iris-setosa
# 15                      16,5.7,4.4,1.5,0.4,Iris-setosa
# ...

# %% [markdown]
# ### “ARFF” - Attribute-Relation File Format (.arff)

# %%
import pandas as pd
file=pd.read_csv('FIFA dataset.arff',sep='\t')
file.head()
# Out:
#   Id,SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCm,Species
# 0                      1,5.1,3.5,1.4,0.2,Iris-setosa
# 1                      2,4.9,3.0,1.4,0.2,Iris-setosa
# 2                      3,4.7,3.2,1.3,0.2,Iris-setosa
# 3                      4,4.6,3.1,1.5,0.2,Iris-setosa
# 4                      5,5.0,3.6,1.4,0.2,Iris-setosa

# %% [markdown]
# ### 2. Read and display the spreadsheet files

# %% [markdown]
# ### "XLSX" — Excel spreadsheet (.xls)

# %%
import pandas as pd
file=("WorldCup2022_ScoreChart_no_macro_20221218.xlsx")
a=pd.read_excel(file)
a
# Out:
#    FIFA WORLD CUP 2022 SCORE CHART               Unnamed: 1  Unnamed: 2  \
# 0                              NaN                      NaN  Time Zone:
# 1                                1                      Sun      20-Nov
# 2                                2                      Mon      21-Nov
# 3                               18                      Fri      25-Nov
# 4                               19                      Fri      25-Nov
# 5                               35                      Tue      29-Nov
# 6                               36                      Tue      29-Nov
# 7                                3                      Mon      21-Nov
# 8                                4                      Mon      21-Nov
# 9                               17                      Fri      25-Nov
# 10                              20                      Fri      25-Nov
# 11                              33                      Tue      29-Nov
# ...

# %% [markdown]
# ### "XLS" — Excel spreadsheet (.xls)

# %%
import pandas as pd
file=("WorldCup2022_ScoreChart_no_macro_20221218.xls")
a=pd.read_excel(file)
a
# Out:
#    FIFA WORLD CUP 2022 SCORE CHART               Unnamed: 1  Unnamed: 2  \
# 0                              NaN                      NaN  Time Zone:
# 1                                1                      Sun      20-Nov
# 2                                2                      Mon      21-Nov
# 3                               18                      Fri      25-Nov
# 4                               19                      Fri      25-Nov
# 5                               35                      Tue      29-Nov
# 6                               36                      Tue      29-Nov
# 7                                3                      Mon      21-Nov
# 8                                4                      Mon      21-Nov
# 9                               17                      Fri      25-Nov
# 10                              20                      Fri      25-Nov
# 11                              33                      Tue      29-Nov
# ...
