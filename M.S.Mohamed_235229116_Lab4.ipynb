# %% [markdown]
# www.linkedin.com/in/mohamed-zaheerudeen-m-s-790b95226
#
# # Roll number : 235229116
# ## Name : Mohamed Zaheerudeen
# ### LAB-4

# %%
import pandas as pd

# %%
df=pd.read_csv('Ames_House_Sales_Cropped.csv')
df
# Out:
#      BldgType CentralAir  1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  \
# 0        1Fam          Y     856.0     854.0        0.0             3
# 1        1Fam          Y    1262.0       0.0        0.0             3
# 2        1Fam          Y     920.0     866.0        0.0             3
# 3        1Fam          Y     961.0     756.0        0.0             3
# 4        1Fam          Y    1145.0    1053.0        0.0             4
# ...       ...        ...       ...       ...        ...           ...
# 1374     1Fam          Y     953.0     694.0        0.0             3
# 1375     1Fam          Y    2073.0       0.0        0.0             3
# 1376     1Fam          Y    1188.0    1152.0        0.0             4
# 1377     1Fam          Y    1078.0       0.0        0.0             2
# 1378     1Fam          Y    1256.0       0.0        0.0             3
#
#       BsmtFinSF1  BsmtFinSF2  BsmtFullBath  BsmtHalfBath  ...  OverallQual  \
# ...

# %%
df.head()
# Out:
#   BldgType CentralAir  1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  \
# 0     1Fam          Y     856.0     854.0        0.0             3
# 1     1Fam          Y    1262.0       0.0        0.0             3
# 2     1Fam          Y     920.0     866.0        0.0             3
# 3     1Fam          Y     961.0     756.0        0.0             3
# 4     1Fam          Y    1145.0    1053.0        0.0             4
#
#    BsmtFinSF1  BsmtFinSF2  BsmtFullBath  BsmtHalfBath  ...  OverallQual  \
# 0       706.0         0.0             1             0  ...            7
# 1       978.0         0.0             0             1  ...            6
# 2       486.0         0.0             1             0  ...            7
# 3       216.0         0.0             1             0  ...            7
# 4       655.0         0.0             1             0  ...            8
#
#    PoolArea  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  YearBuilt  \
# ...

# %%
df.shape
# Out:
# (1379, 39)

# %%
df.columns
# Out:
# Index(['BldgType', 'CentralAir', '1stFlrSF', '2ndFlrSF', '3SsnPorch',
#        'BedroomAbvGr', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtFullBath',
#        'BsmtHalfBath', 'BsmtUnfSF', 'EnclosedPorch', 'Fireplaces', 'FullBath',
#        'GarageArea', 'GarageCars', 'GarageYrBlt', 'GrLivArea', 'HalfBath',
#        'KitchenAbvGr', 'LotArea', 'LotFrontage', 'LowQualFinSF', 'MSSubClass',
#        'MasVnrArea', 'MiscVal', 'MoSold', 'OpenPorchSF', 'OverallCond',
#        'OverallQual', 'PoolArea', 'ScreenPorch', 'TotRmsAbvGrd', 'TotalBsmtSF',
#        'WoodDeckSF', 'YearBuilt', 'YearRemodAdd', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
df.dtypes
# Out:
# BldgType          object
# CentralAir        object
# 1stFlrSF         float64
# 2ndFlrSF         float64
# 3SsnPorch        float64
# BedroomAbvGr       int64
# BsmtFinSF1       float64
# BsmtFinSF2       float64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtUnfSF        float64
# EnclosedPorch    float64
# Fireplaces         int64
# FullBath           int64
# GarageArea       float64
# GarageCars         int64
# GarageYrBlt      float64
# GrLivArea        float64
# HalfBath           int64
# KitchenAbvGr       int64
# LotArea          float64
# LotFrontage      float64
# LowQualFinSF     float64
# MSSubClass         int64
# MasVnrArea       float64
# MiscVal          float64
# MoSold             int64
# OpenPorchSF      float64
# OverallCond        int64
# OverallQual        int64
# PoolArea         float64
# ScreenPorch      float64
# TotRmsAbvGrd       int64
# TotalBsmtSF      float64
# WoodDeckSF       float64
# YearBuilt          int64
# YearRemodAdd       int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379 entries, 0 to 1378
# Data columns (total 39 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BldgType       1379 non-null   object
#  1   CentralAir     1379 non-null   object
#  2   1stFlrSF       1379 non-null   float64
#  3   2ndFlrSF       1379 non-null   float64
#  4   3SsnPorch      1379 non-null   float64
#  5   BedroomAbvGr   1379 non-null   int64
#  6   BsmtFinSF1     1379 non-null   float64
#  7   BsmtFinSF2     1379 non-null   float64
#  8   BsmtFullBath   1379 non-null   int64
#  9   BsmtHalfBath   1379 non-null   int64
#  10  BsmtUnfSF      1379 non-null   float64
#  11  EnclosedPorch  1379 non-null   float64
#  12  Fireplaces     1379 non-null   int64
#  13  FullBath       1379 non-null   int64
#  14  GarageArea     1379 non-null   float64
#  15  GarageCars     1379 non-null   int64
#  16  GarageYrBlt    1379 non-null   float64
# ...

# %%
sr = pd.Series.from_csv('Ames_House_Sales_Cropped.csv')
sr.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sr = pd.Series.from_csv('Ames_House_Sales_Cropped.csv')
#       2 sr.value_counts()
#
# AttributeError: type object 'Series' has no attribute 'from_csv'

# %%
dff=df.drop(["BldgType","CentralAir"],axis=1)
dff
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0        856.0     854.0        0.0             3       706.0         0.0
# 1       1262.0       0.0        0.0             3       978.0         0.0
# 2        920.0     866.0        0.0             3       486.0         0.0
# 3        961.0     756.0        0.0             3       216.0         0.0
# 4       1145.0    1053.0        0.0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1374     953.0     694.0        0.0             3         0.0         0.0
# 1375    2073.0       0.0        0.0             3       790.0       163.0
# 1376    1188.0    1152.0        0.0             4       275.0         0.0
# 1377    1078.0       0.0        0.0             2        49.0      1029.0
# 1378    1256.0       0.0        0.0             3       830.0       290.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallQual  \
# ...

# %%
X=dff.drop(["SalePrice"],axis=1)
X
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0        856.0     854.0        0.0             3       706.0         0.0
# 1       1262.0       0.0        0.0             3       978.0         0.0
# 2        920.0     866.0        0.0             3       486.0         0.0
# 3        961.0     756.0        0.0             3       216.0         0.0
# 4       1145.0    1053.0        0.0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1374     953.0     694.0        0.0             3         0.0         0.0
# 1375    2073.0       0.0        0.0             3       790.0       163.0
# 1376    1188.0    1152.0        0.0             4       275.0         0.0
# 1377    1078.0       0.0        0.0             2        49.0      1029.0
# 1378    1256.0       0.0        0.0             3       830.0       290.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallCond  \
# ...

# %%
X
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0        856.0     854.0        0.0             3       706.0         0.0
# 1       1262.0       0.0        0.0             3       978.0         0.0
# 2        920.0     866.0        0.0             3       486.0         0.0
# 3        961.0     756.0        0.0             3       216.0         0.0
# 4       1145.0    1053.0        0.0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1374     953.0     694.0        0.0             3         0.0         0.0
# 1375    2073.0       0.0        0.0             3       790.0       163.0
# 1376    1188.0    1152.0        0.0             4       275.0         0.0
# 1377    1078.0       0.0        0.0             2        49.0      1029.0
# 1378    1256.0       0.0        0.0             3       830.0       290.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallCond  \
# ...

# %%
y=dff["SalePrice"].values
y
# Out:
# array([208500., 181500., 223500., ..., 266500., 142125., 147500.])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X_test)
y_pred
# Out:
# array([257434.93050743, 111083.73474764, 100018.05832291, 204028.53821318,
#        207319.25418311,  38036.30928935, 234153.38582867, 205076.12689602,
#        187014.12655231, 235636.78799029, 100976.5094378 , 304119.53646993,
#        101769.6460071 , 288758.46001589, 204767.89338326, 145002.47279616,
#        248322.97436859, 151533.68038636, 209697.39458711, 278312.23574164,
#         93329.85601464, 153784.14868379, 163237.87451133, 241495.91212896,
#        372429.9472695 , 221672.07367615, 119658.75685735, 100039.78137072,
#        319435.02892079, 172088.64665033, 258772.64470122, 199597.36129646,
#        156349.69283197, 142311.22500107, 204807.33161319, 379608.17785441,
#        124176.2337755 , 141127.25006137, 273832.43247655, 212547.04205554,
#        169474.57176143, 123305.6571931 , 200341.24016801, 377957.32307098,
#        146941.71712389, 283693.4876067 , 106694.19786716, 221733.02172498,
# ...

# %%
import sklearn.metrics as metrics
mse=metrics.mean_squared_error(y_test,y_pred)
print("MSE without Categorical: ",mse)
# Out:
# MSE without Categorical:  1474827325.5979378

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test,y_pred)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.title("Plot b/w y_test vs y_pred")
plt.show()

# %%
encode=pd.get_dummies(df)
encode
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0        856.0     854.0        0.0             3       706.0         0.0
# 1       1262.0       0.0        0.0             3       978.0         0.0
# 2        920.0     866.0        0.0             3       486.0         0.0
# 3        961.0     756.0        0.0             3       216.0         0.0
# 4       1145.0    1053.0        0.0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1374     953.0     694.0        0.0             3         0.0         0.0
# 1375    2073.0       0.0        0.0             3       790.0       163.0
# 1376    1188.0    1152.0        0.0             4       275.0         0.0
# 1377    1078.0       0.0        0.0             2        49.0      1029.0
# 1378    1256.0       0.0        0.0             3       830.0       290.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  YearRemodAdd  \
# ...

# %%
X=encode.drop(["SalePrice"],axis=1)
X
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0        856.0     854.0        0.0             3       706.0         0.0
# 1       1262.0       0.0        0.0             3       978.0         0.0
# 2        920.0     866.0        0.0             3       486.0         0.0
# 3        961.0     756.0        0.0             3       216.0         0.0
# 4       1145.0    1053.0        0.0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1374     953.0     694.0        0.0             3         0.0         0.0
# 1375    2073.0       0.0        0.0             3       790.0       163.0
# 1376    1188.0    1152.0        0.0             4       275.0         0.0
# 1377    1078.0       0.0        0.0             2        49.0      1029.0
# 1378    1256.0       0.0        0.0             3       830.0       290.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  YearBuilt  \
# ...

# %%
y=encode["SalePrice"].values
y
# Out:
# array([208500., 181500., 223500., ..., 266500., 142125., 147500.])

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

reg=LinearRegression()
reg.fit(X_train,y_train)
y_pred=reg.predict(X_test)
y
# Out:
# array([208500., 181500., 223500., ..., 266500., 142125., 147500.])

# %%
import sklearn.metrics as metrics
mse_cd=metrics.mean_squared_error(y_test,y_pred)
print("MSE with Categorical data: ",mse_cd)
# Out:
# MSE with Categorical data:  1461036570.1435392

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
std_X_train=std.fit_transform(X_train)
std_X_train
# Out:
# array([[ 0.39851037, -0.79290427, -0.11340519, ...,  3.45325933,
#         -0.22777619,  0.22777619],
#        [ 1.57467708, -0.79290427, -0.11340519, ..., -0.2895815 ,
#         -0.22777619,  0.22777619],
#        [ 0.37564751,  0.70143387, -0.11340519, ..., -0.2895815 ,
#         -0.22777619,  0.22777619],
#        ...,
#        [ 1.22157303, -0.79290427, -0.11340519, ..., -0.2895815 ,
#         -0.22777619,  0.22777619],
#        [-1.11297817,  0.90510323, -0.11340519, ..., -0.2895815 ,
#         -0.22777619,  0.22777619],
#        [ 0.11145456, -0.79290427, -0.11340519, ...,  3.45325933,
#         -0.22777619,  0.22777619]])

# %%
std_X_test=std.transform(X_test)
std_X_test
# Out:
# array([[ 0.85830772, -0.79290427, -0.11340519, ...,  3.45325933,
#         -0.22777619,  0.22777619],
#        [-0.64810018, -0.79290427, -0.11340519, ..., -0.2895815 ,
#         -0.22777619,  0.22777619],
#        [-0.21624632,  0.76093278, -0.11340519, ..., -0.2895815 ,
#          4.39027446, -4.39027446],
#        ...,
#        [-0.04350477,  0.37647826, -0.11340519, ..., -0.2895815 ,
#         -0.22777619,  0.22777619],
#        [-0.64301955,  1.46805451, -0.11340519, ..., -0.2895815 ,
#         -0.22777619,  0.22777619],
#        [-0.29499614,  0.81585486, -0.11340519, ...,  3.45325933,
#         -0.22777619,  0.22777619]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(std_X_train,y_train)
std_y_pred=lr.predict(std_X_test)
std_y_pred
# Out:
# array([257979.47562634, 112951.47562634,  82899.47562634, 204199.47562634,
#        208943.47562634,  70035.47562634, 235135.47562634, 205615.47562634,
#        187799.47562634, 234207.47562634, 101519.47562634, 304351.47562634,
#        102171.47562634, 289071.47562634, 204543.47562634, 142087.47562634,
#        249503.47562634, 148063.47562634, 210683.47562634, 277623.47562634,
#         91455.47562634, 154155.47562634, 160631.47562634, 242907.47562634,
#        372599.47562634, 219943.47562634, 116687.47562634, 100679.47562634,
#        318735.47562634, 168183.47562634, 258095.47562634, 201175.47562634,
#        154259.47562634, 142679.47562634, 205387.47562634, 382351.47562634,
#        125103.47562634, 141943.47562634, 273631.47562634, 214155.47562634,
#        170375.47562634, 124519.47562634, 197711.47562634, 376511.47562634,
#        147999.47562634, 288279.47562634, 108519.47562634, 218487.47562634,
# ...

# %%
std_mse=metrics.mean_squared_error(y_test,std_y_pred)
print("Mean Squared Error: ",std_mse)
# Out:
# Mean Squared Error:  1461177519.3770533

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
mm_X_train=mm.fit_transform(X_train)
mm_X_test=mm.transform(X_test)

reg.fit(mm_X_train,y_train)
mm_y_pred=reg.predict(mm_X_test)
mm_y_pred
# Out:
# array([258688., 113280.,  82688., 203904., 208768.,  69632., 234880.,
#        205568., 187776., 234240., 101248., 304256., 102912., 289024.,
#        204544., 142208., 249344., 147456., 211456., 277120.,  91008.,
#        154624., 160640., 244480., 372224., 219904., 116736., 100480.,
#        318720., 167808., 257664., 201472., 154880., 142720., 205952.,
#        382336., 124672., 141312., 273536., 215168., 170240., 124288.,
#        197760., 376704., 148096., 288384., 108544., 218240.,  88448.,
#        295168., 125568.,  54784., 133248., 174208., 214528., 110592.,
#        101376., 198528., 140032., 313216.,  71680., 184960., 153600.,
#        299264.,  76544., 324224., 165760., 112768., 201472., 206208.,
#        130560., 272256., 118912., 145920.,  74752., 138496.,  36864.,
#        163840., 274944., 115712., 319872., 218624., 294016., 211584.,
#         91008., 265856., 142208., 118144., 143232., 279168., 269696.,
# ...

# %%
mm_mse=metrics.mean_squared_error(y_test,mm_y_pred)
print("Mean Squared Error: ",mm_mse)
# Out:
# Mean Squared Error:  1464333847.7014494

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()
sgd.fit(std_X_train, y_train)
sgd_y_pred=sgd.predict(std_X_test)
sgd_y_pred
# Out:
# array([261704.85027668, 102305.86161171,  84317.23476177, 205014.32151444,
#        212479.90507319,  54262.50853184, 241586.40031174, 208644.62770717,
#        185507.3282279 , 234306.93169104,  87669.94145333, 310649.63661353,
#         97200.34251355, 304042.9631019 , 212841.78919215, 139593.70308922,
#        256814.18052717, 144599.3472592 , 216333.19170811, 287843.83801095,
#         86286.8050381 , 151458.69197817, 157413.99271387, 247600.44308274,
#        399222.66336776, 222156.60566582, 111669.52302583,  89634.53662542,
#        335910.07666209, 169193.97150814, 259097.93209384, 204009.08762698,
#        150925.07878544, 134527.48152083, 208764.39417262, 397045.84933892,
#        110688.22271521, 131686.81939379, 278610.07281457, 218111.76806808,
#        171053.82979809, 116300.0207315 , 195308.089936  , 388370.6276156 ,
#        145861.34163303, 301682.85556702,  95857.06471683, 222532.2907644 ,
# ...

# %%
sgd_mse=metrics.mean_squared_error(y_test, sgd_y_pred)
print("Mean Squared Error:",sgd_mse)
# Out:
# Mean Squared Error: 1664385402.630317

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()
ridge.fit(std_X_train, y_train)
ridge_y_pred=ridge.predict(std_X_test)
ridge_y_pred
# Out:
# array([257716.40699318, 113188.83783395,  83441.68622523, 204093.86685461,
#        209046.77119427,  68968.95970424, 235166.85073532, 205709.18701907,
#        187608.88092308, 234127.91986613, 101442.61753652, 303996.83085985,
#        102207.81104997, 289201.83025972, 204530.52882459, 142227.09469735,
#        249528.85892308, 147950.18211509, 210586.82424174, 277366.73836724,
#         91543.67482183, 153978.54592712, 160695.6139235 , 243057.53405206,
#        372495.11731184, 219840.91884082, 116956.95574687, 100878.46795325,
#        318603.53970706, 168136.34840742, 258058.73912129, 201180.97018482,
#        154470.04859036, 142707.68415143, 205133.17128488, 382062.98759242,
#        124795.49109482, 141435.74207829, 273560.58911851, 214075.03676925,
#        170494.5832031 , 124523.92339387, 197429.91336254, 375822.0370805 ,
#        148108.22483297, 288075.31154386, 108608.62662542, 218573.47618249,
# ...

# %%
ridge_mse=metrics.mean_squared_error(y_test, ridge_y_pred)
print("RIDGE Mean Squared Error:",ridge_mse)
# Out:
# RIDGE Mean Squared Error: 1458946958.0904398

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()
lasso.fit(std_X_train, y_train)
lasso_y_pred=lasso.predict(std_X_test)
lasso_y_pred
# Out:
# C:\Users\moham\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.554e+11, tolerance: 6.588e+08
#   model = cd_fast.enet_coordinate_descent(
# array([257729.69686228, 113247.68204486,  83142.29454527, 204106.43998851,
#        209066.49021888,  69054.81228021, 235176.11930442, 205711.84838767,
#        187608.59515698, 234284.06084395, 101449.25460271, 304193.6360213 ,
#        102109.0711376 , 289198.43257911, 204491.12189758, 142122.85239194,
#        249633.03850946, 147889.3873303 , 210566.82234788, 277458.74148889,
#         91422.16023407, 153936.54170005, 160629.24135716, 243131.57205681,
#        372542.62040315, 219872.31056047, 116863.87010022, 100885.24049767,
#        318608.68254302, 168098.13679091, 258090.97848895, 201288.31490053,
# ...

# %%
lasso_mse=metrics.mean_squared_error(y_test, lasso_y_pred)
print("LASSO Mean Squared Error:",lasso_mse)
# Out:
# LASSO Mean Squared Error: 1460906418.1159067

# %%
import numpy as np

# %%
np.sqrt(mse)
# Out:
# 38403.480644310584

# %%
np.sqrt(mse_cd)
# Out:
# 38223.50808263861

# %%
np.sqrt(std_mse)
# Out:
# 38225.35178879395

# %%
np.sqrt(mm_mse)
# Out:
# 38266.61531546067

# %%
np.sqrt(sgd_mse)
# Out:
# 40796.879814886786

# %%
np.sqrt(ridge_mse)
# Out:
# 38196.164180326276

# %%
np.sqrt(lasso_mse)
# Out:
# 38221.80553186763
